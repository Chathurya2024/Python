# %%
import pandas as pd

# Read the metadata CSV file
metadata_df = pd.read_csv('papers.csv')

# Filter the metadata for each primary category
db_df = metadata_df[metadata_df['primary_category'] == 'cs.DB']
gr_df = metadata_df[metadata_df['primary_category'] == 'cs.GR']
ro_df = metadata_df[metadata_df['primary_category'] == 'cs.RO']
et_df = metadata_df[metadata_df['primary_category'] == 'cs.ET']

# Display the first 5 rows of each primary category
print("Databases (cs.DB):")
print(db_df.head())
print("\nGraphics (cs.GR):")
print(gr_df.head())
print("\nRobotics (cs.RO):")
print(ro_df.head())
print("\nEmerging Technologies (cs.ET):")
print(et_df.head())
# Out:
# Databases (cs.DB):
#                                                title  \
# 0  Graph Based Proactive Secure Decomposition Alg...
# 1    CLX: Towards verifiable PBE data transformation
# 2  MaskLink: Efficient Link Discovery for Spatial...
# 3  Imprecise temporal associations and decision s...
# 4          Data Curation with Deep Learning [Vision]
#
#                                              authors  \
# 0  ['Ugur Turan', 'Ismail H. Toroslu', 'Murat Kan...
# 1  ['Zhongjun Jin', 'Michael Cafarella', 'H. V. J...
# 2  ['Georgios Santipantakis', 'Christos Doulkerid...
# 3                              ['Giovanni Vincenti']
# 4  ['Saravanan Thirumuruganathan', 'Nan Tang', 'M...
#
#                                              summary  year  \
# 0    Relational DBMSs continue to dominate the da...  2018
# 1    Effective data analytics on data collected f...  2018
# 2    In this paper, we study the problem of spati...  2018
# 3    The quick and pervasive infiltration of deci...  2018
# ...
